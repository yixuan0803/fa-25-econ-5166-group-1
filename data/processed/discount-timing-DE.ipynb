# %% [markdown]
# # Data Description
# - Author: 方珮潔、黃書佑
# - Date first created: 20251026
# - Background: 此資料表來自 `discount-timing-processed-code.ipynb` 之結果
# - Unit of observation: 25,646
# - Sample period: 20230501 ~ 20250831
# - Known issues:
#     - 僅考慮有一定規模的遊戲。
#     - 無法捕捉非季節性促銷。
# - Definition for each variable:
#     - `Date`: datetime，當次折扣的日期。
#     - `GameID`: object，該遊戲 unique 的 ID。
#     - `Type`: object，該遊戲的類型。
#     - `MultiPlayer`: int，該遊戲是否屬多人遊戲。
#     - `Publisher`: object，該遊戲的出版商名稱。
#     - `ConstantDiscount`: int，該遊戲的折扣幅度是否固定。
#     - `DiscountOrNot`: int，當天是否有折扣。
#     - `Age`: float，折扣當下距該遊戲發布多少年。
#     - `AccumulatedPositiveRate`: float，該遊戲累計至折扣當下的總評價正面率。
#     - `SalePeriod`: int，當次折扣是否位於季節性促銷期間。
#     - `PlayerGrowthRate1W`: float，玩家數一週的移動平均增長率。
#     - `PlayerGrowthRate2W`:float，玩家數兩週的移動平均增長率。
#     - `PlayerGrowthRate1M`: float，玩家數一個月的移動平均增長率。
#     - `FollowersGrowthRate1W`:float，追蹤人數一週的增長率。
#     - `FollowersGrowthRate2W`:float，追蹤人數兩週的增長率。
#     - `FollowersGrowthRate1M`: float，追蹤人數一個月的增長率。
#     - `PositiveRateGrowthRate1W`:float，評價正面率一週的增長率。
#     - `PositiveRateGrowthRate2W`:float，評價正面率兩週的增長率。
#     - `PositiveRateGrowthRate1M`:float，評價正面率一個月的增長率。
#     - `DaysSinceLastDLC`:int，距離上一次 DLC 推出間隔幾天。（-1 表在這之前並未推出過任何 DLC）
#     - `DaysSinceLastSequel`:int，距離上一次續作推出間隔幾天。（-1 表示在這之前並未推出過任何續作）

# %%
import pandas as pd

# %% [markdown]
# ## Change for Your Own Data

# %%
input_data_file = "/Users/peijiefang/Downloads/data analysis project/discount-timing-DE.csv"

# %%
df = pd.read_csv(input_data_file)

# %% [markdown]
# ### Sample

# %%
df.head(10)
# Out:
#          Date  GameID    Type  MultiPlayer Publisher  ConstantDiscount  \
# 0  2023-05-01      10  Action            1     Valve                 0
# 1  2023-05-02      10  Action            1     Valve                 0
# 2  2023-05-03      10  Action            1     Valve                 0
# 3  2023-05-04      10  Action            1     Valve                 0
# 4  2023-05-05      10  Action            1     Valve                 0
# 5  2023-05-06      10  Action            1     Valve                 0
# 6  2023-05-07      10  Action            1     Valve                 0
# 7  2023-05-08      10  Action            1     Valve                 0
# 8  2023-05-09      10  Action            1     Valve                 0
# 9  2023-05-10      10  Action            1     Valve                 0
#
#    DiscountOrNot        Age  AccumulatedPositiveRate  SalePeriod  ...  \
# 0              0  22.509589                 0.975206           0  ...
# 1              0  22.512329                 0.975184           0  ...
# 2              0  22.515068                 0.975189           0  ...
# 3              0  22.517808                 0.975183           0  ...
# 4              0  22.520548                 0.975170           0  ...
# 5              0  22.523288                 0.975180           0  ...
# 6              0  22.526027                 0.975180           0  ...
# 7              0  22.528767                 0.975177           0  ...
# 8              0  22.531507                 0.975176           0  ...
# 9              0  22.534247                 0.975175           0  ...
#
#    FollowersGrowthRate1M  PositiveRateGrowthRate1W  PositiveRateGrowthRate2W  \
# 0               0.003889                  0.000012                 -0.000014
# 1               0.003913                 -0.000010                 -0.000036
# 2               0.003979                 -0.000011                 -0.000041
# 3               0.004101                 -0.000012                 -0.000050
# 4               0.003912                 -0.000023                 -0.000053
# 5               0.003780                 -0.000020                 -0.000024
# 6               0.003789                 -0.000027                 -0.000029
# 7               0.003773                 -0.000029                 -0.000017
# 8               0.003788                 -0.000008                 -0.000018
# 9               0.003722                 -0.000014                 -0.000025
#
#    PositiveRateGrowthRate1M  DLC_sum_7d  DLC_sum_14d  DLC_sum_1m  \
# 0              1.098178e-05           0            0           0
# 1             -4.698912e-07           0            0           0
# 2             -8.082766e-07           0            0           0
# 3             -2.450820e-05           0            0           0
# 4             -3.754777e-05           0            0           0
# 5             -2.712693e-05           0            0           0
# 6             -2.743809e-05           0            0           0
# 7             -3.130728e-05           0            0           0
# 8             -2.608948e-05           0            0           0
# 9             -3.241372e-05           0            0           0
#
#    Sequel_sum_7d  Sequel_sum_14d  Sequel_sum_1m
# 0              0               0              0
# 1              0               0              0
# 2              0               0              0
# 3              0               0              0
# 4              0               0              0
# 5              0               0              0
# 6              0               0              0
# 7              0               0              0
# 8              0               0              0
# 9              0               0              0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Summary Stats

# %%
df.describe().T
# Out:
#                             count           mean            std        min  \
# GameID                    25646.0  455807.277938  289441.376301  10.000000
# MultiPlayer               25646.0       0.433323       0.495544   0.000000
# ConstantDiscount          25646.0       0.200109       0.400090   0.000000
# DiscountOrNot             25646.0       0.021251       0.144222   0.000000
# Age                       25646.0       7.700101       4.320673   2.389041
# AccumulatedPositiveRate   25646.0       0.901407       0.119404   0.425325
# SalePeriod                25646.0       0.418506       0.493324   0.000000
# PlayerGrowthRate1W        25646.0      34.968290     620.875734  -0.999953
# PlayerGrowthRate2W        25646.0       9.112464     204.031743  -0.999915
# PlayerGrowthRate1M        25646.0       2.403977      83.381244  -0.999824
# FollowersGrowthRate1W     25646.0       0.001468       0.001504  -0.003436
# FollowersGrowthRate2W     25646.0       0.002942       0.002804  -0.003436
# FollowersGrowthRate1M     25646.0       0.006348       0.005597  -0.005146
# PositiveRateGrowthRate1W  25646.0       0.000042       0.000642  -0.015190
# PositiveRateGrowthRate2W  25646.0       0.000083       0.000973  -0.016712
# PositiveRateGrowthRate1M  25646.0       0.000176       0.001566  -0.017811
# DLC_sum_7d                25646.0       0.004367       0.069399   0.000000
# DLC_sum_14d               25646.0       0.008734       0.098347   0.000000
# DLC_sum_1m                25646.0       0.019184       0.145185   0.000000
# Sequel_sum_7d             25646.0       0.001092       0.033025   0.000000
# Sequel_sum_14d            25646.0       0.002184       0.046679   0.000000
# Sequel_sum_1m             25646.0       0.004679       0.068245   0.000000
#
#                                     25%            50%            75%  \
# GameID                    244850.000000  423710.000000  588650.000000
# MultiPlayer                    0.000000       0.000000       1.000000
# ConstantDiscount               0.000000       0.000000       0.000000
# DiscountOrNot                  0.000000       0.000000       0.000000
# Age                            5.050000       6.547945       8.654795
# AccumulatedPositiveRate        0.884433       0.952804       0.971957
# SalePeriod                     0.000000       0.000000       1.000000
# PlayerGrowthRate1W            -0.066871      -0.013602       0.039314
# PlayerGrowthRate2W            -0.093327      -0.013276       0.068762
# PlayerGrowthRate1M            -0.114153      -0.008213       0.102662
# FollowersGrowthRate1W          0.000551       0.001045       0.001986
# FollowersGrowthRate2W          0.001150       0.002140       0.003974
# FollowersGrowthRate1M          0.002610       0.004753       0.008629
# PositiveRateGrowthRate1W      -0.000023       0.000003       0.000043
# PositiveRateGrowthRate2W      -0.000040       0.000008       0.000080
# PositiveRateGrowthRate1M      -0.000077       0.000015       0.000170
# DLC_sum_7d                     0.000000       0.000000       0.000000
# DLC_sum_14d                    0.000000       0.000000       0.000000
# DLC_sum_1m                     0.000000       0.000000       0.000000
# Sequel_sum_7d                  0.000000       0.000000       0.000000
# Sequel_sum_14d                 0.000000       0.000000       0.000000
# Sequel_sum_1m                  0.000000       0.000000       0.000000
#
#                                    max
# GameID                    1.145360e+06
# MultiPlayer               1.000000e+00
# ConstantDiscount          1.000000e+00
# DiscountOrNot             1.000000e+00
# Age                       2.484658e+01
# AccumulatedPositiveRate   9.929734e-01
# SalePeriod                1.000000e+00
# PlayerGrowthRate1W        2.456343e+04
# PlayerGrowthRate2W        1.387045e+04
# PlayerGrowthRate1M        5.505114e+03
# FollowersGrowthRate1W     2.296777e-02
# FollowersGrowthRate2W     3.623771e-02
# FollowersGrowthRate1M     5.282514e-02
# PositiveRateGrowthRate1W  1.709402e-02
# PositiveRateGrowthRate2W  1.709402e-02
# PositiveRateGrowthRate1M  1.804671e-02
# DLC_sum_7d                2.000000e+00
# DLC_sum_14d               2.000000e+00
# DLC_sum_1m                2.000000e+00
# Sequel_sum_7d             1.000000e+00
# Sequel_sum_14d            1.000000e+00
# Sequel_sum_1m             1.000000e+00

# %%
df.columns
# Out:
# Index(['Date', 'GameID', 'Type', 'MultiPlayer', 'Publisher',
#        'ConstantDiscount', 'DiscountOrNot', 'Age', 'AccumulatedPositiveRate',
#        'SalePeriod', 'PlayerGrowthRate1W', 'PlayerGrowthRate2W',
#        'PlayerGrowthRate1M', 'FollowersGrowthRate1W', 'FollowersGrowthRate2W',
#        'FollowersGrowthRate1M', 'PositiveRateGrowthRate1W',
#        'PositiveRateGrowthRate2W', 'PositiveRateGrowthRate1M', 'DLC_sum_7d',
#        'DLC_sum_14d', 'DLC_sum_1m', 'Sequel_sum_7d', 'Sequel_sum_14d',
#        'Sequel_sum_1m'],
#       dtype='object')

# %% [markdown]
# ### Assertions

# %%
# Write assertions here—conditions that should always hold in the data.
# Use them to demonstrate that you have carefully checked the data’s correctness.

# %% [markdown]
# #### 日期範圍檢查

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

start_date = pd.to_datetime('2023-05-01')
end_date   = pd.to_datetime('2025-08-31')

assert df['Date'].notna().all(), "Date 欄有缺失值！"
assert ((df['Date'] >= start_date) & (df['Date'] <= end_date)).all(), "Date 不在指定範圍！"

# %% [markdown]
# #### 缺失值檢查

# %%
df.isna().sum()
# Out:
# Date                        0
# GameID                      0
# Type                        0
# MultiPlayer                 0
# Publisher                   0
# ConstantDiscount            0
# DiscountOrNot               0
# Age                         0
# AccumulatedPositiveRate     0
# SalePeriod                  0
# PlayerGrowthRate1W          0
# PlayerGrowthRate2W          0
# PlayerGrowthRate1M          0
# FollowersGrowthRate1W       0
# FollowersGrowthRate2W       0
# FollowersGrowthRate1M       0
# PositiveRateGrowthRate1W    0
# PositiveRateGrowthRate2W    0
# PositiveRateGrowthRate1M    0
# DLC_sum_7d                  0
# DLC_sum_14d                 0
# DLC_sum_1m                  0
# Sequel_sum_7d               0
# Sequel_sum_14d              0
# Sequel_sum_1m               0
# dtype: int64

# %%
# 數值範圍檢查請見 summary stats
